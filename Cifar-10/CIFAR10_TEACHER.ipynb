# %%
# coding: utf-8

# In[2]:


from __future__ import print_function
import keras
from keras.layers import Dense, Conv2D, BatchNormalization, Activation
from keras.layers import AveragePooling2D, Input, Flatten
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2
from keras import backend as K
from keras.models import Model
from keras.datasets import cifar10
import numpy as np
import os


batch_size = 32
epochs = 200
data_augmentation = True
num_classes = 10

subtract_pixel_mean = True


# In[ ]:


# Model parameter
# ----------------------------------------------------------------------------
#           |      | 200-epoch | Orig Paper| 200-epoch | Orig Paper| sec/epoch
# Model     |  n   | ResNet v1 | ResNet v1 | ResNet v2 | ResNet v2 | GTX1080Ti
#           |v1(v2)| %Accuracy | %Accuracy | %Accuracy | %Accuracy | v1 (v2)
# ----------------------------------------------------------------------------
# ResNet20  | 3 (2)| 92.16     | 91.25     | -----     | -----     | 35 (---)
# ResNet32  | 5(NA)| 92.46     | 92.49     | NA        | NA        | 50 ( NA)
# ResNet44  | 7(NA)| 92.50     | 92.83     | NA        | NA        | 70 ( NA)
# ResNet56  | 9 (6)| 92.71     | 93.03     | 93.01     | NA        | 90 (100)
# ResNet110 |18(12)| 92.65     | 93.39+-.16| 93.15     | 93.63     | 165(180)
# ResNet164 |27(18)| -----     | 94.07     | -----     | 94.54     | ---(---)
# ResNet1001| (111)| -----     | 92.39     | -----     | 95.08+-.14| ---(---)
# ---------------------------------------------------------------------------
n = 3

# Model version
# Orig paper: version = 1 (ResNet v1), Improved ResNet: version = 2 (ResNet v2)
version = 1

# Computed depth from supplied model parameter n
if version == 1:
    depth = n * 6 + 2
elif version == 2:
    depth = n * 9 + 2

# Model name, depth and version
model_type = 'ResNet%dv%d' % (depth, version)

# Load the CIFAR10 data.
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# Input image dimensions.
input_shape = x_train.shape[1:]

# Normalize data.
x_train = x_train.astype('float32')/255 
x_test = x_test.astype('float32')/255

# If subtract pixel mean is enabled
if subtract_pixel_mean:
    x_train_mean = np.mean(x_train, axis=0)
    x_train -= x_train_mean
    x_test -= x_train_mean

# print('x_train shape:', x_train.shape)
# print(x_train.shape[0], 'train samples')
# print(x_test.shape[0], 'test samples')
# print('y_train shape:', y_train.shape)

# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %%
# In[ ]:


def lr_schedule(epoch):
    """Learning Rate Schedule

    Learning rate is scheduled to be reduced after 80, 120, 160, 180 epochs.
    Called automatically every epoch as part of callbacks during training.

    # Arguments
        epoch (int): The number of epochs

    # Returns
        lr (float32): learning rate
    """
    lr = 1e-3
    if epoch > 180:
        lr *= 0.5e-3
    elif epoch > 160:
        lr *= 1e-3
    elif epoch > 120:
        lr *= 1e-2
    elif epoch > 80:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr


def resnet_layer(inputs,
                 num_filters=16,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=True,
                 conv_first=True):
    """2D Convolution-Batch Normalization-Activation stack builder

    # Arguments
        inputs (tensor): input tensor from input image or previous layer
        num_filters (int): Conv2D number of filters
        kernel_size (int): Conv2D square kernel dimensions
        strides (int): Conv2D square stride dimensions
        activation (string): activation name
        batch_normalization (bool): whether to include batch normalization
        conv_first (bool): conv-bn-activation (True) or
            bn-activation-conv (False)

    # Returns
        x (tensor): tensor as input to the next layer
    """
    conv = Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))

    x = inputs
    if conv_first:
        x = conv(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x


def resnet_v1(input_shape, depth, num_classes=10):
    """ResNet Version 1 Model builder [a]

    Stacks of 2 x (3 x 3) Conv2D-BN-ReLU
    Last ReLU is after the shortcut connection.
    At the beginning of each stage, the feature map size is halved (downsampled)
    by a convolutional layer with strides=2, while the number of filters is
    doubled. Within each stage, the layers have the same number filters and the
    same number of filters.
    Features maps sizes:
    stage 0: 32x32, 16
    stage 1: 16x16, 32
    stage 2:  8x8,  64
    The Number of parameters is approx the same as Table 6 of [a]:
    ResNet20 0.27M
    ResNet32 0.46M
    ResNet44 0.66M
    ResNet56 0.85M
    ResNet110 1.7M

    # Arguments
        input_shape (tensor): shape of input image tensor
        depth (int): number of core convolutional layers
        num_classes (int): number of classes (CIFAR10 has 10)

    # Returns
        model (Model): Keras model instance
    """
    if (depth - 2) % 6 != 0:
        raise ValueError('depth should be 6n+2 (eg 20, 32, 44 in [a])')
    # Start model definition.
    num_filters = 16
    num_res_blocks = int((depth - 2) / 6)

    inputs = Input(shape=input_shape)
    x = resnet_layer(inputs=inputs)
    # Instantiate the stack of residual units
    for stack in range(3):
        for res_block in range(num_res_blocks):
            strides = 1
            if stack > 0 and res_block == 0:  # first layer but not first stack
                strides = 2  # downsample
            y = resnet_layer(inputs=x,
                             num_filters=num_filters,
                             strides=strides)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters,
                             activation=None)
            if stack > 0 and res_block == 0:  # first layer but not first stack
                # linear projection residual shortcut connection to match
                # changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])
            x = Activation('relu')(x)
        num_filters *= 2

    # Add classifier on top.
    # v1 does not use BN after last shortcut connection-ReLU
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model


def resnet_v2(input_shape, depth, num_classes=10):
    """ResNet Version 2 Model builder [b]

    Stacks of (1 x 1)-(3 x 3)-(1 x 1) BN-ReLU-Conv2D or also known as
    bottleneck layer
    First shortcut connection per layer is 1 x 1 Conv2D.
    Second and onwards shortcut connection is identity.
    At the beginning of each stage, the feature map size is halved (downsampled)
    by a convolutional layer with strides=2, while the number of filter maps is
    doubled. Within each stage, the layers have the same number filters and the
    same filter map sizes.
    Features maps sizes:
    conv1  : 32x32,  16
    stage 0: 32x32,  64
    stage 1: 16x16, 128
    stage 2:  8x8,  256

    # Arguments
        input_shape (tensor): shape of input image tensor
        depth (int): number of core convolutional layers
        num_classes (int): number of classes (CIFAR10 has 10)

    # Returns
        model (Model): Keras model instance
    """
    if (depth - 2) % 9 != 0:
        raise ValueError('depth should be 9n+2 (eg 56 or 110 in [b])')
    # Start model definition.
    num_filters_in = 16
    num_res_blocks = int((depth - 2) / 9)

    inputs = Input(shape=input_shape)
    # v2 performs Conv2D with BN-ReLU on input before splitting into 2 paths
    x = resnet_layer(inputs=inputs,
                     num_filters=num_filters_in,
                     conv_first=True)

    # Instantiate the stack of residual units
    for stage in range(3):
        for res_block in range(num_res_blocks):
            activation = 'relu'
            batch_normalization = True
            strides = 1
            if stage == 0:
                num_filters_out = num_filters_in * 4
                if res_block == 0:  # first layer and first stage
                    activation = None
                    batch_normalization = False
            else:
                num_filters_out = num_filters_in * 2
                if res_block == 0:  # first layer but not first stage
                    strides = 2    # downsample

            # bottleneck residual unit
            y = resnet_layer(inputs=x,
                             num_filters=num_filters_in,
                             kernel_size=1,
                             strides=strides,
                             activation=activation,
                             batch_normalization=batch_normalization,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_in,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_out,
                             kernel_size=1,
                             conv_first=False)
            if res_block == 0:
                # linear projection residual shortcut connection to match
                # changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters_out,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])

        num_filters_in = num_filters_out

    # Add classifier on top.
    # v2 has BN-ReLU before Pooling
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model


# In[1]:


if version == 2:
    model = resnet_v2(input_shape=input_shape, depth=depth)
else:
    model = resnet_v1(input_shape=input_shape, depth=depth)
    
model.compile(loss='categorical_crossentropy',
              optimizer=Adam(lr=lr_schedule(0)),
              metrics=['accuracy'])
model.summary()
print(model_type)

# Prepare model model saving directory.
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'cifar10_%s_model.{epoch:03d}.h5' % model_type
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)

# Prepare callbacks for model saving and for learning rate adjustment.
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_acc',
                             verbose=1,
                             save_best_only=True)

lr_scheduler = LearningRateScheduler(lr_schedule)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)

callbacks = [checkpoint, lr_reducer, lr_scheduler]
# Out:
# Learning rate:  0.001
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 16)   448         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 32, 16)   64          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 32, 32, 16)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 16)   2320        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32, 32, 16)   64          conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 32, 32, 16)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, 32, 16)   2320        activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 32, 32, 16)   64          conv2d_3[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 32, 32, 16)   0           activation_1[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 32, 32, 16)   0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 16)   2320        activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 32, 32, 16)   64          conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 32, 32, 16)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 16)   2320        activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, 32, 16)   64          conv2d_5[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 32, 32, 16)   0           activation_3[0][0]
#                                                                  batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 32, 32, 16)   0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 16)   2320        activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 32, 32, 16)   64          conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 32, 32, 16)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 16)   2320        activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 32, 32, 16)   64          conv2d_7[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 32, 32, 16)   0           activation_5[0][0]
#                                                                  batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 32, 32, 16)   0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 32)   4640        activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 16, 16, 32)   128         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 16, 16, 32)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 32)   9248        activation_8[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 32)   544         activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 16, 16, 32)   128         conv2d_9[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 16, 16, 32)   0           conv2d_10[0][0]
#                                                                  batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 16, 16, 32)   0           add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 16, 16, 32)   9248        activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 16, 16, 32)   128         conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 16, 16, 32)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 16, 32)   9248        activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 16, 16, 32)   128         conv2d_12[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 16, 16, 32)   0           activation_9[0][0]
#                                                                  batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 16, 16, 32)   0           add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 16, 16, 32)   9248        activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 16, 16, 32)   128         conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 16, 16, 32)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 16, 16, 32)   9248        activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 16, 16, 32)   128         conv2d_14[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 16, 16, 32)   0           activation_11[0][0]
#                                                                  batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 16, 16, 32)   0           add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 8, 8, 64)     18496       activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 8, 8, 64)     256         conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 8, 8, 64)     0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 8, 8, 64)     36928       activation_14[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 8, 8, 64)     2112        activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 8, 8, 64)     256         conv2d_16[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 8, 8, 64)     0           conv2d_17[0][0]
#                                                                  batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 8, 8, 64)     0           add_7[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 8, 8, 64)     36928       activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 8, 8, 64)     256         conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 8, 8, 64)     0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 8, 8, 64)     36928       activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 8, 8, 64)     256         conv2d_19[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 8, 8, 64)     0           activation_15[0][0]
#                                                                  batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 8, 8, 64)     0           add_8[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 8, 8, 64)     36928       activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 8, 8, 64)     256         conv2d_20[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 8, 8, 64)     0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 8, 8, 64)     36928       activation_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 8, 8, 64)     256         conv2d_21[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 8, 8, 64)     0           activation_17[0][0]
#                                                                  batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 8, 8, 64)     0           add_9[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 1, 1, 64)     0           activation_19[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 64)           0           average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 10)           650         flatten_1[0][0]
# ==================================================================================================
# Total params: 274,442
# Trainable params: 273,066
# Non-trainable params: 1,376
# __________________________________________________________________________________________________
# ResNet20v1

# %%
# Run training, with or without data augmentation.
if not data_augmentation:
    print('Not using data augmentation.')
    model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              shuffle=True,
              callbacks=callbacks)
else:
    print('Using real-time data augmentation.')
    # This will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
        # set input mean to 0 over the dataset
        featurewise_center=False,
        # set each sample mean to 0
        samplewise_center=False,
        # divide inputs by std of dataset
        featurewise_std_normalization=False,
        # divide each input by its std
        samplewise_std_normalization=False,
        # apply ZCA whitening
        zca_whitening=False,
        # epsilon for ZCA whitening
        zca_epsilon=1e-06,
        # randomly rotate images in the range (deg 0 to 180)
        rotation_range=0,
        # randomly shift images horizontally
        width_shift_range=0.1,
        # randomly shift images vertically
        height_shift_range=0.1,
        # set range for random shear
        shear_range=0.,
        # set range for random zoom
        zoom_range=0.,
        # set range for random channel shifts
        channel_shift_range=0.,
        # set mode for filling points outside the input boundaries
        fill_mode='nearest',
        # value used for fill_mode = "constant"
        cval=0.,
        # randomly flip images
        horizontal_flip=True,
        # randomly flip images
        vertical_flip=False,
        # set rescaling factor (applied before any other transformation)
        rescale=None,
        # set function that will be applied on each input
        preprocessing_function=None,
        # image data format, either "channels_first" or "channels_last"
        data_format=None,
        # fraction of images reserved for validation (strictly between 0 and 1)
        validation_split=0.0)

    # Compute quantities required for featurewise normalization
    # (std, mean, and principal components if ZCA whitening is applied).
    datagen.fit(x_train)

#     # Fit the model on the batches generated by datagen.flow().
    model.fit_generator(datagen.flow(x_train, y_train, batch_size=batch_size),
                        validation_data=(x_test, y_test),
                        epochs=epochs, verbose=1, workers=4,
                        callbacks=callbacks)
# Out:
# Learning rate:  0.001
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_6 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# conv2d_106 (Conv2D)             (None, 32, 32, 16)   448         input_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_96 (BatchNo (None, 32, 32, 16)   64          conv2d_106[0][0]
# __________________________________________________________________________________________________
# activation_96 (Activation)      (None, 32, 32, 16)   0           batch_normalization_96[0][0]
# __________________________________________________________________________________________________
# conv2d_107 (Conv2D)             (None, 32, 32, 16)   2320        activation_96[0][0]
# __________________________________________________________________________________________________
# batch_normalization_97 (BatchNo (None, 32, 32, 16)   64          conv2d_107[0][0]
# __________________________________________________________________________________________________
# activation_97 (Activation)      (None, 32, 32, 16)   0           batch_normalization_97[0][0]
# __________________________________________________________________________________________________
# conv2d_108 (Conv2D)             (None, 32, 32, 16)   2320        activation_97[0][0]
# __________________________________________________________________________________________________
# batch_normalization_98 (BatchNo (None, 32, 32, 16)   64          conv2d_108[0][0]
# __________________________________________________________________________________________________
# add_46 (Add)                    (None, 32, 32, 16)   0           activation_96[0][0]
#                                                                  batch_normalization_98[0][0]
# __________________________________________________________________________________________________
# activation_98 (Activation)      (None, 32, 32, 16)   0           add_46[0][0]
# __________________________________________________________________________________________________
# conv2d_109 (Conv2D)             (None, 32, 32, 16)   2320        activation_98[0][0]
# __________________________________________________________________________________________________
# batch_normalization_99 (BatchNo (None, 32, 32, 16)   64          conv2d_109[0][0]
# __________________________________________________________________________________________________
# activation_99 (Activation)      (None, 32, 32, 16)   0           batch_normalization_99[0][0]
# __________________________________________________________________________________________________
# conv2d_110 (Conv2D)             (None, 32, 32, 16)   2320        activation_99[0][0]
# __________________________________________________________________________________________________
# batch_normalization_100 (BatchN (None, 32, 32, 16)   64          conv2d_110[0][0]
# __________________________________________________________________________________________________
# add_47 (Add)                    (None, 32, 32, 16)   0           activation_98[0][0]
#                                                                  batch_normalization_100[0][0]
# __________________________________________________________________________________________________
# activation_100 (Activation)     (None, 32, 32, 16)   0           add_47[0][0]
# __________________________________________________________________________________________________
# conv2d_111 (Conv2D)             (None, 32, 32, 16)   2320        activation_100[0][0]
# __________________________________________________________________________________________________
# batch_normalization_101 (BatchN (None, 32, 32, 16)   64          conv2d_111[0][0]
# __________________________________________________________________________________________________
# activation_101 (Activation)     (None, 32, 32, 16)   0           batch_normalization_101[0][0]
# __________________________________________________________________________________________________
# conv2d_112 (Conv2D)             (None, 32, 32, 16)   2320        activation_101[0][0]
# __________________________________________________________________________________________________
# batch_normalization_102 (BatchN (None, 32, 32, 16)   64          conv2d_112[0][0]
# __________________________________________________________________________________________________
# add_48 (Add)                    (None, 32, 32, 16)   0           activation_100[0][0]
#                                                                  batch_normalization_102[0][0]
# __________________________________________________________________________________________________
# activation_102 (Activation)     (None, 32, 32, 16)   0           add_48[0][0]
# __________________________________________________________________________________________________
# conv2d_113 (Conv2D)             (None, 16, 16, 32)   4640        activation_102[0][0]
# __________________________________________________________________________________________________
# batch_normalization_103 (BatchN (None, 16, 16, 32)   128         conv2d_113[0][0]
# __________________________________________________________________________________________________
# activation_103 (Activation)     (None, 16, 16, 32)   0           batch_normalization_103[0][0]
# __________________________________________________________________________________________________
# conv2d_114 (Conv2D)             (None, 16, 16, 32)   9248        activation_103[0][0]
# __________________________________________________________________________________________________
# conv2d_115 (Conv2D)             (None, 16, 16, 32)   544         activation_102[0][0]
# __________________________________________________________________________________________________
# batch_normalization_104 (BatchN (None, 16, 16, 32)   128         conv2d_114[0][0]
# __________________________________________________________________________________________________
# add_49 (Add)                    (None, 16, 16, 32)   0           conv2d_115[0][0]
#                                                                  batch_normalization_104[0][0]
# __________________________________________________________________________________________________
# activation_104 (Activation)     (None, 16, 16, 32)   0           add_49[0][0]
# __________________________________________________________________________________________________
# conv2d_116 (Conv2D)             (None, 16, 16, 32)   9248        activation_104[0][0]
# __________________________________________________________________________________________________
# batch_normalization_105 (BatchN (None, 16, 16, 32)   128         conv2d_116[0][0]
# __________________________________________________________________________________________________
# activation_105 (Activation)     (None, 16, 16, 32)   0           batch_normalization_105[0][0]
# __________________________________________________________________________________________________
# conv2d_117 (Conv2D)             (None, 16, 16, 32)   9248        activation_105[0][0]
# __________________________________________________________________________________________________
# batch_normalization_106 (BatchN (None, 16, 16, 32)   128         conv2d_117[0][0]
# __________________________________________________________________________________________________
# add_50 (Add)                    (None, 16, 16, 32)   0           activation_104[0][0]
#                                                                  batch_normalization_106[0][0]
# __________________________________________________________________________________________________
# activation_106 (Activation)     (None, 16, 16, 32)   0           add_50[0][0]
# __________________________________________________________________________________________________
# conv2d_118 (Conv2D)             (None, 16, 16, 32)   9248        activation_106[0][0]
# __________________________________________________________________________________________________
# batch_normalization_107 (BatchN (None, 16, 16, 32)   128         conv2d_118[0][0]
# __________________________________________________________________________________________________
# activation_107 (Activation)     (None, 16, 16, 32)   0           batch_normalization_107[0][0]
# __________________________________________________________________________________________________
# conv2d_119 (Conv2D)             (None, 16, 16, 32)   9248        activation_107[0][0]
# __________________________________________________________________________________________________
# batch_normalization_108 (BatchN (None, 16, 16, 32)   128         conv2d_119[0][0]
# __________________________________________________________________________________________________
# add_51 (Add)                    (None, 16, 16, 32)   0           activation_106[0][0]
#                                                                  batch_normalization_108[0][0]
# __________________________________________________________________________________________________
# activation_108 (Activation)     (None, 16, 16, 32)   0           add_51[0][0]
# __________________________________________________________________________________________________
# conv2d_120 (Conv2D)             (None, 8, 8, 64)     18496       activation_108[0][0]
# __________________________________________________________________________________________________
# batch_normalization_109 (BatchN (None, 8, 8, 64)     256         conv2d_120[0][0]
# __________________________________________________________________________________________________
# activation_109 (Activation)     (None, 8, 8, 64)     0           batch_normalization_109[0][0]
# __________________________________________________________________________________________________
# conv2d_121 (Conv2D)             (None, 8, 8, 64)     36928       activation_109[0][0]
# __________________________________________________________________________________________________
# conv2d_122 (Conv2D)             (None, 8, 8, 64)     2112        activation_108[0][0]
# __________________________________________________________________________________________________
# batch_normalization_110 (BatchN (None, 8, 8, 64)     256         conv2d_121[0][0]
# __________________________________________________________________________________________________
# add_52 (Add)                    (None, 8, 8, 64)     0           conv2d_122[0][0]
#                                                                  batch_normalization_110[0][0]
# __________________________________________________________________________________________________
# activation_110 (Activation)     (None, 8, 8, 64)     0           add_52[0][0]
# __________________________________________________________________________________________________
# conv2d_123 (Conv2D)             (None, 8, 8, 64)     36928       activation_110[0][0]
# __________________________________________________________________________________________________
# batch_normalization_111 (BatchN (None, 8, 8, 64)     256         conv2d_123[0][0]
# __________________________________________________________________________________________________
# activation_111 (Activation)     (None, 8, 8, 64)     0           batch_normalization_111[0][0]
# __________________________________________________________________________________________________
# conv2d_124 (Conv2D)             (None, 8, 8, 64)     36928       activation_111[0][0]
# __________________________________________________________________________________________________
# batch_normalization_112 (BatchN (None, 8, 8, 64)     256         conv2d_124[0][0]
# __________________________________________________________________________________________________
# add_53 (Add)                    (None, 8, 8, 64)     0           activation_110[0][0]
#                                                                  batch_normalization_112[0][0]
# __________________________________________________________________________________________________
# activation_112 (Activation)     (None, 8, 8, 64)     0           add_53[0][0]
# __________________________________________________________________________________________________
# conv2d_125 (Conv2D)             (None, 8, 8, 64)     36928       activation_112[0][0]
# __________________________________________________________________________________________________
# batch_normalization_113 (BatchN (None, 8, 8, 64)     256         conv2d_125[0][0]
# __________________________________________________________________________________________________
# activation_113 (Activation)     (None, 8, 8, 64)     0           batch_normalization_113[0][0]
# __________________________________________________________________________________________________
# conv2d_126 (Conv2D)             (None, 8, 8, 64)     36928       activation_113[0][0]
# __________________________________________________________________________________________________
# batch_normalization_114 (BatchN (None, 8, 8, 64)     256         conv2d_126[0][0]
# __________________________________________________________________________________________________
# add_54 (Add)                    (None, 8, 8, 64)     0           activation_112[0][0]
#                                                                  batch_normalization_114[0][0]
# __________________________________________________________________________________________________
# activation_114 (Activation)     (None, 8, 8, 64)     0           add_54[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_6 (AveragePoo (None, 1, 1, 64)     0           activation_114[0][0]
# __________________________________________________________________________________________________
# flatten_6 (Flatten)             (None, 64)           0           average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 10)           650         flatten_6[0][0]
# ==================================================================================================
# Total params: 274,442
# Trainable params: 273,066
# Non-trainable params: 1,376
# __________________________________________________________________________________________________
# ResNet20v1
# Using real-time data augmentation.
# Epoch 1/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.4886 - acc: 0.9092 - val_loss: 0.6147 - val_acc: 0.8459
#
# Epoch 00001: val_acc improved from -inf to 0.84590, saving model to /home/sahil/Uttaran/saved_models/cifar10_ResNet20v1_model.001.h5
# Epoch 2/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.4963 - acc: 0.9057 - val_loss: 0.6022 - val_acc: 0.8511
#
# Epoch 00002: val_acc improved from 0.84590 to 0.85110, saving model to /home/sahil/Uttaran/saved_models/cifar10_ResNet20v1_model.002.h5
# Epoch 3/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.5081 - acc: 0.9015 - val_loss: 0.6368 - val_acc: 0.8424
#
# Epoch 00003: val_acc did not improve from 0.85110
# Epoch 4/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.5172 - acc: 0.9001 - val_loss: 0.6355 - val_acc: 0.8425
#
# Epoch 00004: val_acc did not improve from 0.85110
# Epoch 5/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.5210 - acc: 0.8994 - val_loss: 0.7194 - val_acc: 0.8283
#
# Epoch 00005: val_acc did not improve from 0.85110
# Epoch 6/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.5256 - acc: 0.9005 - val_loss: 0.5927 - val_acc: 0.8579
#
# Epoch 00006: val_acc improved from 0.85110 to 0.85790, saving model to /home/sahil/Uttaran/saved_models/cifar10_ResNet20v1_model.006.h5
# Epoch 7/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.5263 - acc: 0.8987 - val_loss: 0.5685 - val_acc: 0.8630
#
# Epoch 00007: val_acc improved from 0.85790 to 0.86300, saving model to /home/sahil/Uttaran/saved_models/cifar10_ResNet20v1_model.007.h5
# Epoch 8/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.5283 - acc: 0.8990 - val_loss: 0.5772 - val_acc: 0.8624
#
# Epoch 00008: val_acc did not improve from 0.86300
# Epoch 9/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.5293 - acc: 0.9004 - val_loss: 0.8033 - val_acc: 0.7995
#
# Epoch 00009: val_acc did not improve from 0.86300
# Epoch 10/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.5349 - acc: 0.8972 - val_loss: 0.6637 - val_acc: 0.8402
#
# Epoch 00010: val_acc did not improve from 0.86300
# Epoch 11/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.5264 - acc: 0.9022 - val_loss: 0.6859 - val_acc: 0.8342
#
# Epoch 00011: val_acc did not improve from 0.86300
# Epoch 12/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.5275 - acc: 0.9008 - val_loss: 0.5901 - val_acc: 0.8545
#
# Epoch 00012: val_acc did not improve from 0.86300
# Epoch 13/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.5277 - acc: 0.8990 - val_loss: 0.6277 - val_acc: 0.8448
#
# Epoch 00013: val_acc did not improve from 0.86300
# Epoch 14/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.5274 - acc: 0.9011 - val_loss: 0.5788 - val_acc: 0.8650
#
# Epoch 00014: val_acc improved from 0.86300 to 0.86500, saving model to /home/sahil/Uttaran/saved_models/cifar10_ResNet20v1_model.014.h5
# Epoch 15/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.5272 - acc: 0.8989 - val_loss: 0.6643 - val_acc: 0.8378
#
# Epoch 00015: val_acc did not improve from 0.86500
# Epoch 16/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.5249 - acc: 0.9016 - val_loss: 0.5625 - val_acc: 0.8650
#
# Epoch 00016: val_acc did not improve from 0.86500
# Epoch 17/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.5227 - acc: 0.9005 - val_loss: 0.5808 - val_acc: 0.8586
#
# Epoch 00017: val_acc did not improve from 0.86500
# Epoch 18/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.5224 - acc: 0.9007 - val_loss: 0.6854 - val_acc: 0.8322
#
# Epoch 00018: val_acc did not improve from 0.86500
# Epoch 19/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.5222 - acc: 0.9007 - val_loss: 0.6050 - val_acc: 0.8532
#
# Epoch 00019: val_acc did not improve from 0.86500
# Epoch 20/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.5192 - acc: 0.9012 - val_loss: 0.6056 - val_acc: 0.8569
#
# Epoch 00020: val_acc did not improve from 0.86500
# Epoch 21/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.5235 - acc: 0.9002 - val_loss: 0.6132 - val_acc: 0.8465
#
# Epoch 00021: val_acc did not improve from 0.86500
# Epoch 22/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.5214 - acc: 0.9028 - val_loss: 0.7193 - val_acc: 0.8230
#
# Epoch 00022: val_acc did not improve from 0.86500
# Epoch 23/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.5210 - acc: 0.9002 - val_loss: 0.6420 - val_acc: 0.8420
#
# Epoch 00023: val_acc did not improve from 0.86500
# Epoch 24/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.5190 - acc: 0.9014 - val_loss: 0.6389 - val_acc: 0.8425
#
# Epoch 00024: val_acc did not improve from 0.86500
# Epoch 25/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.5184 - acc: 0.9017 - val_loss: 0.6448 - val_acc: 0.8445
#
# Epoch 00025: val_acc did not improve from 0.86500
# Epoch 26/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.5179 - acc: 0.9016 - val_loss: 0.6543 - val_acc: 0.8420
#
# Epoch 00026: val_acc did not improve from 0.86500
# Epoch 27/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.5227 - acc: 0.9010 - val_loss: 0.6301 - val_acc: 0.8426
#
# Epoch 00027: val_acc did not improve from 0.86500
# Epoch 28/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.5214 - acc: 0.8997 - val_loss: 0.5835 - val_acc: 0.8554
#
# Epoch 00028: val_acc did not improve from 0.86500
# Epoch 29/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.5229 - acc: 0.8989 - val_loss: 0.6282 - val_acc: 0.8441
#
# Epoch 00029: val_acc did not improve from 0.86500
# Epoch 30/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.5184 - acc: 0.9006 - val_loss: 0.5866 - val_acc: 0.8558
#
# Epoch 00030: val_acc did not improve from 0.86500
# Epoch 31/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.5152 - acc: 0.9029 - val_loss: 0.5523 - val_acc: 0.8645
#
# Epoch 00031: val_acc did not improve from 0.86500
# Epoch 32/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.5145 - acc: 0.9011 - val_loss: 0.6024 - val_acc: 0.8532
#
# Epoch 00032: val_acc did not improve from 0.86500
# Epoch 33/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.5155 - acc: 0.9029 - val_loss: 0.6563 - val_acc: 0.8400
#
# Epoch 00033: val_acc did not improve from 0.86500
# Epoch 34/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.5129 - acc: 0.9031 - val_loss: 0.6399 - val_acc: 0.8422
#
# Epoch 00034: val_acc did not improve from 0.86500
# Epoch 35/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.5140 - acc: 0.9023 - val_loss: 0.7380 - val_acc: 0.8130
#
# Epoch 00035: val_acc did not improve from 0.86500
# Epoch 36/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.5153 - acc: 0.9040 - val_loss: 0.5596 - val_acc: 0.8669
#
# Epoch 00036: val_acc improved from 0.86500 to 0.86690, saving model to /home/sahil/Uttaran/saved_models/cifar10_ResNet20v1_model.036.h5
# Epoch 37/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.5109 - acc: 0.9042 - val_loss: 0.5950 - val_acc: 0.8546
#
# Epoch 00037: val_acc did not improve from 0.86690
# Epoch 38/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.5110 - acc: 0.9029 - val_loss: 0.5926 - val_acc: 0.8568
#
# Epoch 00038: val_acc did not improve from 0.86690
# Epoch 39/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.5092 - acc: 0.9030 - val_loss: 0.6341 - val_acc: 0.8454
#
# Epoch 00039: val_acc did not improve from 0.86690
# Epoch 40/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.5102 - acc: 0.9030 - val_loss: 0.6735 - val_acc: 0.8334
#
# Epoch 00040: val_acc did not improve from 0.86690
# Epoch 41/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 30s 19ms/step - loss: 0.5101 - acc: 0.9032 - val_loss: 0.5697 - val_acc: 0.8669
#
# Epoch 00041: val_acc did not improve from 0.86690
# Epoch 42/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.5114 - acc: 0.9023 - val_loss: 0.6025 - val_acc: 0.8545
#
# Epoch 00042: val_acc did not improve from 0.86690
# Epoch 43/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.5084 - acc: 0.9046 - val_loss: 0.5821 - val_acc: 0.8592
#
# Epoch 00043: val_acc did not improve from 0.86690
# Epoch 44/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.5094 - acc: 0.9037 - val_loss: 0.5677 - val_acc: 0.8686
#
# Epoch 00044: val_acc improved from 0.86690 to 0.86860, saving model to /home/sahil/Uttaran/saved_models/cifar10_ResNet20v1_model.044.h5
# Epoch 45/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.5082 - acc: 0.9050 - val_loss: 0.5670 - val_acc: 0.8652
#
# Epoch 00045: val_acc did not improve from 0.86860
# Epoch 46/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.5083 - acc: 0.9033 - val_loss: 0.5856 - val_acc: 0.8590
#
# Epoch 00046: val_acc did not improve from 0.86860
# Epoch 47/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.5059 - acc: 0.9054 - val_loss: 0.5927 - val_acc: 0.8561
#
# Epoch 00047: val_acc did not improve from 0.86860
# Epoch 48/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.5093 - acc: 0.9040 - val_loss: 0.5725 - val_acc: 0.8605
#
# Epoch 00048: val_acc did not improve from 0.86860
# Epoch 49/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.5074 - acc: 0.9044 - val_loss: 0.5294 - val_acc: 0.8748
#
# Epoch 00049: val_acc improved from 0.86860 to 0.87480, saving model to /home/sahil/Uttaran/saved_models/cifar10_ResNet20v1_model.049.h5
# Epoch 50/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.5074 - acc: 0.9056 - val_loss: 0.5413 - val_acc: 0.8689
#
# Epoch 00050: val_acc did not improve from 0.87480
# Epoch 51/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 30s 19ms/step - loss: 0.5061 - acc: 0.9031 - val_loss: 0.5344 - val_acc: 0.8778
#
# Epoch 00051: val_acc improved from 0.87480 to 0.87780, saving model to /home/sahil/Uttaran/saved_models/cifar10_ResNet20v1_model.051.h5
# Epoch 52/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.5048 - acc: 0.9046 - val_loss: 0.6498 - val_acc: 0.8454
#
# Epoch 00052: val_acc did not improve from 0.87780
# Epoch 53/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.5032 - acc: 0.9061 - val_loss: 0.7220 - val_acc: 0.8192
#
# Epoch 00053: val_acc did not improve from 0.87780
# Epoch 54/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.5044 - acc: 0.9055 - val_loss: 0.5972 - val_acc: 0.8543
#
# Epoch 00054: val_acc did not improve from 0.87780
# Epoch 55/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.5058 - acc: 0.9034 - val_loss: 0.6521 - val_acc: 0.8408
#
# Epoch 00055: val_acc did not improve from 0.87780
# Epoch 56/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.5057 - acc: 0.9044 - val_loss: 0.6144 - val_acc: 0.8481
#
# Epoch 00056: val_acc did not improve from 0.87780
# Epoch 57/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.5026 - acc: 0.9061 - val_loss: 0.6154 - val_acc: 0.8545
#
# Epoch 00057: val_acc did not improve from 0.87780
# Epoch 58/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.5008 - acc: 0.9048 - val_loss: 0.5965 - val_acc: 0.8543
#
# Epoch 00058: val_acc did not improve from 0.87780
# Epoch 59/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.5033 - acc: 0.9044 - val_loss: 0.5814 - val_acc: 0.8636
#
# Epoch 00059: val_acc did not improve from 0.87780
# Epoch 60/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.4986 - acc: 0.9063 - val_loss: 0.6616 - val_acc: 0.8359
#
# Epoch 00060: val_acc did not improve from 0.87780
# Epoch 61/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.5011 - acc: 0.9057 - val_loss: 0.6425 - val_acc: 0.8423
#
# Epoch 00061: val_acc did not improve from 0.87780
# Epoch 62/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.4993 - acc: 0.9051 - val_loss: 0.5863 - val_acc: 0.8613
#
# Epoch 00062: val_acc did not improve from 0.87780
# Epoch 63/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.5004 - acc: 0.9069 - val_loss: 0.6479 - val_acc: 0.8438
#
# Epoch 00063: val_acc did not improve from 0.87780
# Epoch 64/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.4983 - acc: 0.9084 - val_loss: 0.5680 - val_acc: 0.8603
#
# Epoch 00064: val_acc did not improve from 0.87780
# Epoch 65/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.5014 - acc: 0.9057 - val_loss: 0.7324 - val_acc: 0.8200
#
# Epoch 00065: val_acc did not improve from 0.87780
# Epoch 66/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.5036 - acc: 0.9041 - val_loss: 0.5237 - val_acc: 0.8728
#
# Epoch 00066: val_acc did not improve from 0.87780
# Epoch 67/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.5012 - acc: 0.9063 - val_loss: 0.5838 - val_acc: 0.8593
#
# Epoch 00067: val_acc did not improve from 0.87780
# Epoch 68/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.4967 - acc: 0.9076 - val_loss: 0.5910 - val_acc: 0.8558
#
# Epoch 00068: val_acc did not improve from 0.87780
# Epoch 69/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.4977 - acc: 0.9070 - val_loss: 0.6011 - val_acc: 0.8531
#
# Epoch 00069: val_acc did not improve from 0.87780
# Epoch 70/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.4971 - acc: 0.9065 - val_loss: 0.6764 - val_acc: 0.8348
#
# Epoch 00070: val_acc did not improve from 0.87780
# Epoch 71/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.4984 - acc: 0.9066 - val_loss: 0.5475 - val_acc: 0.8679
#
# Epoch 00071: val_acc did not improve from 0.87780
# Epoch 72/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.4981 - acc: 0.9073 - val_loss: 0.5912 - val_acc: 0.8564
#
# Epoch 00072: val_acc did not improve from 0.87780
# Epoch 73/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.4960 - acc: 0.9068 - val_loss: 0.5526 - val_acc: 0.8716
#
# Epoch 00073: val_acc did not improve from 0.87780
# Epoch 74/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.4986 - acc: 0.9056 - val_loss: 0.5428 - val_acc: 0.8721
#
# Epoch 00074: val_acc did not improve from 0.87780
# Epoch 75/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.4953 - acc: 0.9075 - val_loss: 0.5806 - val_acc: 0.8601
#
# Epoch 00075: val_acc did not improve from 0.87780
# Epoch 76/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 30s 19ms/step - loss: 0.4967 - acc: 0.9062 - val_loss: 0.5727 - val_acc: 0.8624
#
# Epoch 00076: val_acc did not improve from 0.87780
# Epoch 77/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.4955 - acc: 0.9077 - val_loss: 0.6281 - val_acc: 0.8457
#
# Epoch 00077: val_acc did not improve from 0.87780
# Epoch 78/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.4949 - acc: 0.9076 - val_loss: 0.5816 - val_acc: 0.8588
#
# Epoch 00078: val_acc did not improve from 0.87780
# Epoch 79/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.4948 - acc: 0.9079 - val_loss: 0.5471 - val_acc: 0.8714
#
# Epoch 00079: val_acc did not improve from 0.87780
# Epoch 80/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.4973 - acc: 0.9068 - val_loss: 0.6162 - val_acc: 0.8498
#
# Epoch 00080: val_acc did not improve from 0.87780
# Epoch 81/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.4945 - acc: 0.9077 - val_loss: 0.5917 - val_acc: 0.8561
#
# Epoch 00081: val_acc did not improve from 0.87780
# Epoch 82/200
# Learning rate:  0.0001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.4322 - acc: 0.9324 - val_loss: 0.4381 - val_acc: 0.9036
#
# Epoch 00082: val_acc improved from 0.87780 to 0.90360, saving model to /home/sahil/Uttaran/saved_models/cifar10_ResNet20v1_model.082.h5
# Epoch 83/200
# Learning rate:  0.0001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.4085 - acc: 0.9405 - val_loss: 0.4232 - val_acc: 0.9098
#
# Epoch 00083: val_acc improved from 0.90360 to 0.90980, saving model to /home/sahil/Uttaran/saved_models/cifar10_ResNet20v1_model.083.h5
# Epoch 84/200
# Learning rate:  0.0001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.3981 - acc: 0.9438 - val_loss: 0.4157 - val_acc: 0.9099
#
# Epoch 00084: val_acc improved from 0.90980 to 0.90990, saving model to /home/sahil/Uttaran/saved_models/cifar10_ResNet20v1_model.084.h5
# Epoch 85/200
# Learning rate:  0.0001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.3886 - acc: 0.9481 - val_loss: 0.4091 - val_acc: 0.9107
#
# Epoch 00085: val_acc improved from 0.90990 to 0.91070, saving model to /home/sahil/Uttaran/saved_models/cifar10_ResNet20v1_model.085.h5
# Epoch 86/200
# Learning rate:  0.0001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.3782 - acc: 0.9496 - val_loss: 0.4026 - val_acc: 0.9120
#
# Epoch 00086: val_acc improved from 0.91070 to 0.91200, saving model to /home/sahil/Uttaran/saved_models/cifar10_ResNet20v1_model.086.h5
# Epoch 87/200
# Learning rate:  0.0001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.3735 - acc: 0.9509 - val_loss: 0.3965 - val_acc: 0.9130
#
# Epoch 00087: val_acc improved from 0.91200 to 0.91300, saving model to /home/sahil/Uttaran/saved_models/cifar10_ResNet20v1_model.087.h5
# Epoch 88/200
# Learning rate:  0.0001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.3659 - acc: 0.9530 - val_loss: 0.3924 - val_acc: 0.9121
#
# Epoch 00088: val_acc did not improve from 0.91300
# Epoch 89/200
# Learning rate:  0.0001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.3628 - acc: 0.9534 - val_loss: 0.3970 - val_acc: 0.9114
#
# Epoch 00089: val_acc did not improve from 0.91300
# Epoch 90/200
# Learning rate:  0.0001
# 1563/1563 [==============================] - 30s 19ms/step - loss: 0.3579 - acc: 0.9540 - val_loss: 0.3874 - val_acc: 0.9126
#
# Epoch 00090: val_acc did not improve from 0.91300
# Epoch 91/200
# Learning rate:  0.0001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.3506 - acc: 0.9552 - val_loss: 0.3780 - val_acc: 0.9150
#
# Epoch 00091: val_acc improved from 0.91300 to 0.91500, saving model to /home/sahil/Uttaran/saved_models/cifar10_ResNet20v1_model.091.h5
# Epoch 92/200
# Learning rate:  0.0001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.3465 - acc: 0.9574 - val_loss: 0.3816 - val_acc: 0.9132
#
# Epoch 00092: val_acc did not improve from 0.91500
# Epoch 93/200
# Learning rate:  0.0001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.3443 - acc: 0.9572 - val_loss: 0.3801 - val_acc: 0.9111
#
# Epoch 00093: val_acc did not improve from 0.91500
# Epoch 94/200
# Learning rate:  0.0001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.3397 - acc: 0.9593 - val_loss: 0.3671 - val_acc: 0.9161
#
# Epoch 00094: val_acc improved from 0.91500 to 0.91610, saving model to /home/sahil/Uttaran/saved_models/cifar10_ResNet20v1_model.094.h5
# Epoch 95/200
# Learning rate:  0.0001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.3355 - acc: 0.9593 - val_loss: 0.3716 - val_acc: 0.9136
#
# Epoch 00095: val_acc did not improve from 0.91610
# Epoch 96/200
# Learning rate:  0.0001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.3319 - acc: 0.9604 - val_loss: 0.3872 - val_acc: 0.9074
#
# Epoch 00096: val_acc did not improve from 0.91610
# Epoch 97/200
# Learning rate:  0.0001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.3303 - acc: 0.9605 - val_loss: 0.3705 - val_acc: 0.9128
#
# Epoch 00097: val_acc did not improve from 0.91610
# Epoch 98/200
# Learning rate:  0.0001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.3258 - acc: 0.9619 - val_loss: 0.3782 - val_acc: 0.9097
#
# Epoch 00098: val_acc did not improve from 0.91610
# Epoch 99/200
# Learning rate:  0.0001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.3200 - acc: 0.9632 - val_loss: 0.3619 - val_acc: 0.9149
#
# Epoch 00099: val_acc did not improve from 0.91610
# Epoch 100/200
# Learning rate:  0.0001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.3193 - acc: 0.9631 - val_loss: 0.3622 - val_acc: 0.9145
#
# Epoch 00100: val_acc did not improve from 0.91610
# Epoch 101/200
# Learning rate:  0.0001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.3175 - acc: 0.9629 - val_loss: 0.3598 - val_acc: 0.9137
#
# Epoch 00101: val_acc did not improve from 0.91610
# Epoch 102/200
# Learning rate:  0.0001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.3137 - acc: 0.9647 - val_loss: 0.3586 - val_acc: 0.9151
#
# Epoch 00102: val_acc did not improve from 0.91610
# Epoch 103/200
# Learning rate:  0.0001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.3113 - acc: 0.9646 - val_loss: 0.3487 - val_acc: 0.9172
#
# Epoch 00103: val_acc improved from 0.91610 to 0.91720, saving model to /home/sahil/Uttaran/saved_models/cifar10_ResNet20v1_model.103.h5
# Epoch 104/200
# Learning rate:  0.0001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.3089 - acc: 0.9660 - val_loss: 0.3543 - val_acc: 0.9148
#
# Epoch 00104: val_acc did not improve from 0.91720
# Epoch 105/200
# Learning rate:  0.0001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.3069 - acc: 0.9653 - val_loss: 0.3499 - val_acc: 0.9148
#
# Epoch 00105: val_acc did not improve from 0.91720
# Epoch 106/200
# Learning rate:  0.0001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.3033 - acc: 0.9661 - val_loss: 0.3792 - val_acc: 0.9092
#
# Epoch 00106: val_acc did not improve from 0.91720
# Epoch 107/200
# Learning rate:  0.0001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.3003 - acc: 0.9670 - val_loss: 0.3585 - val_acc: 0.9126
#
# Epoch 00107: val_acc did not improve from 0.91720
# Epoch 108/200
# Learning rate:  0.0001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2997 - acc: 0.9670 - val_loss: 0.3591 - val_acc: 0.9113
#
# Epoch 00108: val_acc did not improve from 0.91720
# Epoch 109/200
# Learning rate:  0.0001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2983 - acc: 0.9666 - val_loss: 0.3568 - val_acc: 0.9124
#
# Epoch 00109: val_acc did not improve from 0.91720
# Epoch 110/200
# Learning rate:  0.0001
# 1563/1563 [==============================] - 30s 19ms/step - loss: 0.2959 - acc: 0.9673 - val_loss: 0.3491 - val_acc: 0.9159
#
# Epoch 00110: val_acc did not improve from 0.91720
# Epoch 111/200
# Learning rate:  0.0001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2940 - acc: 0.9664 - val_loss: 0.3499 - val_acc: 0.9141
#
# Epoch 00111: val_acc did not improve from 0.91720
# Epoch 112/200
# Learning rate:  0.0001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2921 - acc: 0.9666 - val_loss: 0.3445 - val_acc: 0.9146
#
# Epoch 00112: val_acc did not improve from 0.91720
# Epoch 113/200
# Learning rate:  0.0001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2899 - acc: 0.9689 - val_loss: 0.3427 - val_acc: 0.9149
#
# Epoch 00113: val_acc did not improve from 0.91720
# Epoch 114/200
# Learning rate:  0.0001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2892 - acc: 0.9680 - val_loss: 0.3399 - val_acc: 0.9150
#
# Epoch 00114: val_acc did not improve from 0.91720
# Epoch 115/200
# Learning rate:  0.0001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2870 - acc: 0.9682 - val_loss: 0.3500 - val_acc: 0.9128
#
# Epoch 00115: val_acc did not improve from 0.91720
# Epoch 116/200
# Learning rate:  0.0001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2855 - acc: 0.9679 - val_loss: 0.3318 - val_acc: 0.9187
#
# Epoch 00116: val_acc improved from 0.91720 to 0.91870, saving model to /home/sahil/Uttaran/saved_models/cifar10_ResNet20v1_model.116.h5
# Epoch 117/200
# Learning rate:  0.0001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2828 - acc: 0.9704 - val_loss: 0.3346 - val_acc: 0.9174
#
# Epoch 00117: val_acc did not improve from 0.91870
# Epoch 118/200
# Learning rate:  0.0001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2827 - acc: 0.9689 - val_loss: 0.3538 - val_acc: 0.9107
#
# Epoch 00118: val_acc did not improve from 0.91870
# Epoch 119/200
# Learning rate:  0.0001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2811 - acc: 0.9692 - val_loss: 0.3436 - val_acc: 0.9146
#
# Epoch 00119: val_acc did not improve from 0.91870
# Epoch 120/200
# Learning rate:  0.0001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2804 - acc: 0.9693 - val_loss: 0.3303 - val_acc: 0.9152
#
# Epoch 00120: val_acc did not improve from 0.91870
# Epoch 121/200
# Learning rate:  0.0001
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2771 - acc: 0.9708 - val_loss: 0.3221 - val_acc: 0.9185
#
# Epoch 00121: val_acc did not improve from 0.91870
# Epoch 122/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2724 - acc: 0.9725 - val_loss: 0.3245 - val_acc: 0.9172
#
# Epoch 00122: val_acc did not improve from 0.91870
# Epoch 123/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2686 - acc: 0.9750 - val_loss: 0.3270 - val_acc: 0.9170
#
# Epoch 00123: val_acc did not improve from 0.91870
# Epoch 124/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2675 - acc: 0.9756 - val_loss: 0.3256 - val_acc: 0.9166
#
# Epoch 00124: val_acc did not improve from 0.91870
# Epoch 125/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2654 - acc: 0.9747 - val_loss: 0.3246 - val_acc: 0.9174
#
# Epoch 00125: val_acc did not improve from 0.91870
# Epoch 126/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2663 - acc: 0.9754 - val_loss: 0.3227 - val_acc: 0.9177
#
# Epoch 00126: val_acc did not improve from 0.91870
# Epoch 127/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2663 - acc: 0.9757 - val_loss: 0.3222 - val_acc: 0.9187
#
# Epoch 00127: val_acc did not improve from 0.91870
# Epoch 128/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2651 - acc: 0.9764 - val_loss: 0.3229 - val_acc: 0.9161
#
# Epoch 00128: val_acc did not improve from 0.91870
# Epoch 129/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2650 - acc: 0.9757 - val_loss: 0.3236 - val_acc: 0.9182
#
# Epoch 00129: val_acc did not improve from 0.91870
# Epoch 130/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2643 - acc: 0.9761 - val_loss: 0.3230 - val_acc: 0.9170
#
# Epoch 00130: val_acc did not improve from 0.91870
# Epoch 131/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2646 - acc: 0.9754 - val_loss: 0.3235 - val_acc: 0.9170
#
# Epoch 00131: val_acc did not improve from 0.91870
# Epoch 132/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2639 - acc: 0.9760 - val_loss: 0.3243 - val_acc: 0.9171
#
# Epoch 00132: val_acc did not improve from 0.91870
# Epoch 133/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2619 - acc: 0.9771 - val_loss: 0.3269 - val_acc: 0.9174
#
# Epoch 00133: val_acc did not improve from 0.91870
# Epoch 134/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2632 - acc: 0.9772 - val_loss: 0.3251 - val_acc: 0.9170
#
# Epoch 00134: val_acc did not improve from 0.91870
# Epoch 135/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2620 - acc: 0.9757 - val_loss: 0.3225 - val_acc: 0.9172
#
# Epoch 00135: val_acc did not improve from 0.91870
# Epoch 136/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2622 - acc: 0.9767 - val_loss: 0.3211 - val_acc: 0.9172
#
# Epoch 00136: val_acc did not improve from 0.91870
# Epoch 137/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2622 - acc: 0.9760 - val_loss: 0.3228 - val_acc: 0.9176
#
# Epoch 00137: val_acc did not improve from 0.91870
# Epoch 138/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2619 - acc: 0.9768 - val_loss: 0.3231 - val_acc: 0.9183
#
# Epoch 00138: val_acc did not improve from 0.91870
# Epoch 139/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2622 - acc: 0.9762 - val_loss: 0.3240 - val_acc: 0.9181
#
# Epoch 00139: val_acc did not improve from 0.91870
# Epoch 140/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2617 - acc: 0.9765 - val_loss: 0.3241 - val_acc: 0.9174
#
# Epoch 00140: val_acc did not improve from 0.91870
# Epoch 141/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2607 - acc: 0.9774 - val_loss: 0.3214 - val_acc: 0.9179
#
# Epoch 00141: val_acc did not improve from 0.91870
# Epoch 142/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2607 - acc: 0.9771 - val_loss: 0.3212 - val_acc: 0.9180
#
# Epoch 00142: val_acc did not improve from 0.91870
# Epoch 143/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2607 - acc: 0.9768 - val_loss: 0.3221 - val_acc: 0.9173
#
# Epoch 00143: val_acc did not improve from 0.91870
# Epoch 144/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2603 - acc: 0.9774 - val_loss: 0.3233 - val_acc: 0.9169
#
# Epoch 00144: val_acc did not improve from 0.91870
# Epoch 145/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2607 - acc: 0.9767 - val_loss: 0.3205 - val_acc: 0.9180
#
# Epoch 00145: val_acc did not improve from 0.91870
# Epoch 146/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2602 - acc: 0.9772 - val_loss: 0.3197 - val_acc: 0.9187
#
# Epoch 00146: val_acc did not improve from 0.91870
# Epoch 147/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2585 - acc: 0.9783 - val_loss: 0.3199 - val_acc: 0.9182
#
# Epoch 00147: val_acc did not improve from 0.91870
# Epoch 148/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2584 - acc: 0.9772 - val_loss: 0.3195 - val_acc: 0.9193
#
# Epoch 00148: val_acc improved from 0.91870 to 0.91930, saving model to /home/sahil/Uttaran/saved_models/cifar10_ResNet20v1_model.148.h5
# Epoch 149/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2579 - acc: 0.9784 - val_loss: 0.3216 - val_acc: 0.9182
#
# Epoch 00149: val_acc did not improve from 0.91930
# Epoch 150/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2590 - acc: 0.9772 - val_loss: 0.3190 - val_acc: 0.9192
#
# Epoch 00150: val_acc did not improve from 0.91930
# Epoch 151/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2585 - acc: 0.9777 - val_loss: 0.3209 - val_acc: 0.9181
#
# Epoch 00151: val_acc did not improve from 0.91930
# Epoch 152/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2572 - acc: 0.9786 - val_loss: 0.3187 - val_acc: 0.9187
#
# Epoch 00152: val_acc did not improve from 0.91930
# Epoch 153/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2581 - acc: 0.9772 - val_loss: 0.3202 - val_acc: 0.9177
#
# Epoch 00153: val_acc did not improve from 0.91930
# Epoch 154/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2566 - acc: 0.9786 - val_loss: 0.3177 - val_acc: 0.9186
#
# Epoch 00154: val_acc did not improve from 0.91930
# Epoch 155/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2574 - acc: 0.9781 - val_loss: 0.3208 - val_acc: 0.9185
#
# Epoch 00155: val_acc did not improve from 0.91930
# Epoch 156/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2565 - acc: 0.9784 - val_loss: 0.3194 - val_acc: 0.9186
#
# Epoch 00156: val_acc did not improve from 0.91930
# Epoch 157/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2565 - acc: 0.9786 - val_loss: 0.3201 - val_acc: 0.9175
#
# Epoch 00157: val_acc did not improve from 0.91930
# Epoch 158/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2565 - acc: 0.9775 - val_loss: 0.3208 - val_acc: 0.9182
#
# Epoch 00158: val_acc did not improve from 0.91930
# Epoch 159/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2571 - acc: 0.9781 - val_loss: 0.3186 - val_acc: 0.9179
#
# Epoch 00159: val_acc did not improve from 0.91930
# Epoch 160/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2555 - acc: 0.9791 - val_loss: 0.3176 - val_acc: 0.9192
#
# Epoch 00160: val_acc did not improve from 0.91930
# Epoch 161/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2559 - acc: 0.9782 - val_loss: 0.3190 - val_acc: 0.9186
#
# Epoch 00161: val_acc did not improve from 0.91930
# Epoch 162/200
# Learning rate:  1e-06
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2545 - acc: 0.9791 - val_loss: 0.3190 - val_acc: 0.9180
#
# Epoch 00162: val_acc did not improve from 0.91930
# Epoch 163/200
# Learning rate:  1e-06
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2556 - acc: 0.9782 - val_loss: 0.3192 - val_acc: 0.9177
#
# Epoch 00163: val_acc did not improve from 0.91930
# Epoch 164/200
# Learning rate:  1e-06
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2550 - acc: 0.9782 - val_loss: 0.3166 - val_acc: 0.9179
#
# Epoch 00164: val_acc did not improve from 0.91930
# Epoch 165/200
# Learning rate:  1e-06
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2543 - acc: 0.9794 - val_loss: 0.3163 - val_acc: 0.9185
#
# Epoch 00165: val_acc did not improve from 0.91930
# Epoch 166/200
# Learning rate:  1e-06
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2554 - acc: 0.9787 - val_loss: 0.3174 - val_acc: 0.9180
#
# Epoch 00166: val_acc did not improve from 0.91930
# Epoch 167/200
# Learning rate:  1e-06
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2547 - acc: 0.9786 - val_loss: 0.3177 - val_acc: 0.9172
#
# Epoch 00167: val_acc did not improve from 0.91930
# Epoch 168/200
# Learning rate:  1e-06
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2558 - acc: 0.9778 - val_loss: 0.3182 - val_acc: 0.9171
#
# Epoch 00168: val_acc did not improve from 0.91930
# Epoch 169/200
# Learning rate:  1e-06
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2546 - acc: 0.9779 - val_loss: 0.3181 - val_acc: 0.9176
#
# Epoch 00169: val_acc did not improve from 0.91930
# Epoch 170/200
# Learning rate:  1e-06
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2548 - acc: 0.9789 - val_loss: 0.3180 - val_acc: 0.9180
#
# Epoch 00170: val_acc did not improve from 0.91930
# Epoch 171/200
# Learning rate:  1e-06
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2550 - acc: 0.9787 - val_loss: 0.3180 - val_acc: 0.9175
#
# Epoch 00171: val_acc did not improve from 0.91930
# Epoch 172/200
# Learning rate:  1e-06
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2553 - acc: 0.9785 - val_loss: 0.3172 - val_acc: 0.9175
#
# Epoch 00172: val_acc did not improve from 0.91930
# Epoch 173/200
# Learning rate:  1e-06
# 1563/1563 [==============================] - 30s 19ms/step - loss: 0.2545 - acc: 0.9787 - val_loss: 0.3168 - val_acc: 0.9181
#
# Epoch 00173: val_acc did not improve from 0.91930
# Epoch 174/200
# Learning rate:  1e-06
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2555 - acc: 0.9791 - val_loss: 0.3173 - val_acc: 0.9174
#
# Epoch 00174: val_acc did not improve from 0.91930
# Epoch 175/200
# Learning rate:  1e-06
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2550 - acc: 0.9786 - val_loss: 0.3175 - val_acc: 0.9170
#
# Epoch 00175: val_acc did not improve from 0.91930
# Epoch 176/200
# Learning rate:  1e-06
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2546 - acc: 0.9785 - val_loss: 0.3171 - val_acc: 0.9177
#
# Epoch 00176: val_acc did not improve from 0.91930
# Epoch 177/200
# Learning rate:  1e-06
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2538 - acc: 0.9793 - val_loss: 0.3167 - val_acc: 0.9182
#
# Epoch 00177: val_acc did not improve from 0.91930
# Epoch 178/200
# Learning rate:  1e-06
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2537 - acc: 0.9793 - val_loss: 0.3178 - val_acc: 0.9177
#
# Epoch 00178: val_acc did not improve from 0.91930
# Epoch 179/200
# Learning rate:  1e-06
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2533 - acc: 0.9793 - val_loss: 0.3188 - val_acc: 0.9174
#
# Epoch 00179: val_acc did not improve from 0.91930
# Epoch 180/200
# Learning rate:  1e-06
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2550 - acc: 0.9786 - val_loss: 0.3183 - val_acc: 0.9173
#
# Epoch 00180: val_acc did not improve from 0.91930
# Epoch 181/200
# Learning rate:  1e-06
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2542 - acc: 0.9788 - val_loss: 0.3169 - val_acc: 0.9176
#
# Epoch 00181: val_acc did not improve from 0.91930
# Epoch 182/200
# Learning rate:  5e-07
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2553 - acc: 0.9781 - val_loss: 0.3184 - val_acc: 0.9176
#
# Epoch 00182: val_acc did not improve from 0.91930
# Epoch 183/200
# Learning rate:  5e-07
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2544 - acc: 0.9797 - val_loss: 0.3173 - val_acc: 0.9181
#
# Epoch 00183: val_acc did not improve from 0.91930
# Epoch 184/200
# Learning rate:  5e-07
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2547 - acc: 0.9793 - val_loss: 0.3176 - val_acc: 0.9186
#
# Epoch 00184: val_acc did not improve from 0.91930
# Epoch 185/200
# Learning rate:  5e-07
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2542 - acc: 0.9791 - val_loss: 0.3174 - val_acc: 0.9172
#
# Epoch 00185: val_acc did not improve from 0.91930
# Epoch 186/200
# Learning rate:  5e-07
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2536 - acc: 0.9804 - val_loss: 0.3168 - val_acc: 0.9179
#
# Epoch 00186: val_acc did not improve from 0.91930
# Epoch 187/200
# Learning rate:  5e-07
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2547 - acc: 0.9777 - val_loss: 0.3169 - val_acc: 0.9179
#
# Epoch 00187: val_acc did not improve from 0.91930
# Epoch 188/200
# Learning rate:  5e-07
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2535 - acc: 0.9792 - val_loss: 0.3173 - val_acc: 0.9182
#
# Epoch 00188: val_acc did not improve from 0.91930
# Epoch 189/200
# Learning rate:  5e-07
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2540 - acc: 0.9788 - val_loss: 0.3172 - val_acc: 0.9183
#
# Epoch 00189: val_acc did not improve from 0.91930
# Epoch 190/200
# Learning rate:  5e-07
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2541 - acc: 0.9784 - val_loss: 0.3179 - val_acc: 0.9179
#
# Epoch 00190: val_acc did not improve from 0.91930
# Epoch 191/200
# Learning rate:  5e-07
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2549 - acc: 0.9784 - val_loss: 0.3164 - val_acc: 0.9183
#
# Epoch 00191: val_acc did not improve from 0.91930
# Epoch 192/200
# Learning rate:  5e-07
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2546 - acc: 0.9788 - val_loss: 0.3164 - val_acc: 0.9182
#
# Epoch 00192: val_acc did not improve from 0.91930
# Epoch 193/200
# Learning rate:  5e-07
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2544 - acc: 0.9789 - val_loss: 0.3183 - val_acc: 0.9174
#
# Epoch 00193: val_acc did not improve from 0.91930
# Epoch 194/200
# Learning rate:  5e-07
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2537 - acc: 0.9799 - val_loss: 0.3169 - val_acc: 0.9180
#
# Epoch 00194: val_acc did not improve from 0.91930
# Epoch 195/200
# Learning rate:  5e-07
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2537 - acc: 0.9792 - val_loss: 0.3172 - val_acc: 0.9181
#
# Epoch 00195: val_acc did not improve from 0.91930
# Epoch 196/200
# Learning rate:  5e-07
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2529 - acc: 0.9798 - val_loss: 0.3169 - val_acc: 0.9181
#
# Epoch 00196: val_acc did not improve from 0.91930
# Epoch 197/200
# Learning rate:  5e-07
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2534 - acc: 0.9792 - val_loss: 0.3164 - val_acc: 0.9183
#
# Epoch 00197: val_acc did not improve from 0.91930
# Epoch 198/200
# Learning rate:  5e-07
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2545 - acc: 0.9788 - val_loss: 0.3155 - val_acc: 0.9188
#
# Epoch 00198: val_acc did not improve from 0.91930
# Epoch 199/200
# Learning rate:  5e-07
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2532 - acc: 0.9793 - val_loss: 0.3172 - val_acc: 0.9174
#
# Epoch 00199: val_acc did not improve from 0.91930
# Epoch 200/200
# Learning rate:  5e-07
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.2535 - acc: 0.9792 - val_loss: 0.3163 - val_acc: 0.9184
#
# Epoch 00200: val_acc did not improve from 0.91930

# %%
model.load_weights("")
model.evaluate(x_test,y_test)
# Out:
# 10000/10000 [==============================] - 10s 1ms/step
# [0.4571079341411591, 0.9108]
